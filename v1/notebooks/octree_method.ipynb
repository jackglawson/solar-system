# %%
from solar_system import *
from params import *
from visualise import *
import matplotlib.pyplot as plt
import itertools
import time

# %%
import sys
import os
cwd = os.getcwd()
new_path = cwd[:-len('\\solar_system')]
if new_path not in sys.path:
    sys.path.insert(0, cwd[:-len('\\solar_system')])
from data_structures.ntree import NTreeNode, NTree

# %%
y_0, ms = generate_initial_conditions()
n = p.num_particles
rs = y_0[:int(len(y_0) / 2)].reshape((n, p.num_dimensions))
vs = y_0[int(len(y_0) / 2):].reshape((n, p.num_dimensions))
# Out:
# Initialised 500 particles

# %%
np.max(rs)
# Out:
# 48.70637950807229

# %%
octree = Octree(np.array([0, 0, 0]), 100, rs, ms)

# %%
plt.figure(figsize=(10, 10))
octree.plot(rs)

# %%
# %timeit octree.find_acc_v(rs, ms)
# Out:
# 698 ms ± 21.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit find_acc_v(rs, ms, 500)
# Out:
# 50.6 ms ± 954 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
def plot(whole_solution):
    for i in range(p.num_particles):
        plt.scatter(*whole_solution.rs[:, i, 0:2].T)
    plt.show()

# %%
plot(old)

# %%
plot(new)

# %%
old_diff_g = unpickle('solution_old_diff_G.pkl')
plot(old_diff_g)

# %%
old = unpickle('solution_old.pkl')
new = unpickle('solution_octree_0.pkl')

old.rs == new.rs
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        ...,
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
# ...
